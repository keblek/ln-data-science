# %%
# %matplotlib inline

# %% [markdown]
# # Cleaning data
#
# `$ lncli describegrabh # a small three node lightning network`
#
# ```json
# {
#     "nodes": [
#         {
#             "last_update": 1614859519,
#             "pub_key": "02e7857b03623747741064fdd161a9a7579b6b5af178cf2836895b8f755843a7d7",
#             "alias": "bob",
#             "addresses": [
#             ],
#             "color": "#02e785",
#             "features": {
#                 "1": {
#                     "name": "data-loss-protect",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "5": {
#                     "name": "upfront-shutdown-script",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "7": {
#                     "name": "gossip-queries",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "9": {
#                     "name": "tlv-onion",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "11": {
#                     "name": "unknown",
#                     "is_required": false,
#                     "is_known": false
#                 },
#                 "13": {
#                     "name": "static-remote-key",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "15": {
#                     "name": "payment-addr",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "17": {
#                     "name": "multi-path-payments",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "55": {
#                     "name": "unknown",
#                     "is_required": false,
#                     "is_known": false
#                 }
#             }
#         },
#         {
#             "last_update": 1616493354,
#             "pub_key": "03f5f96163d4868f91358134dd95b162d0d3b1951612d63cf9cf94657ff602e6ec",
#             "alias": "alice",
#             "addresses": [
#                 {
#                     "network": "tcp",
#                     "addr": "172.20.0.2:9735"
#                 }
#             ],
#             "color": "#3399ff",
#             "features": {
#                 "0": {
#                     "name": "data-loss-protect",
#                     "is_required": true,
#                     "is_known": true
#                 },
#                 "5": {
#                     "name": "upfront-shutdown-script",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "7": {
#                     "name": "gossip-queries",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "9": {
#                     "name": "tlv-onion",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "12": {
#                     "name": "static-remote-key",
#                     "is_required": true,
#                     "is_known": true
#                 },
#                 "14": {
#                     "name": "payment-addr",
#                     "is_required": true,
#                     "is_known": true
#                 },
#                 "17": {
#                     "name": "multi-path-payments",
#                     "is_required": false,
#                     "is_known": true
#                 }
#             }
#         },
#         {
#             "last_update": 1616493357,
#             "pub_key": "03f706f9a86e0bb0cb1a812eef2abb9f2a2910bdcae792f4f6a3d5c817fedb8104",
#             "alias": "carol",
#             "addresses": [
#                 {
#                     "network": "tcp",
#                     "addr": "172.20.0.4:9735"
#                 }
#             ],
#             "color": "#49daaa",
#             "features": {
#                 "1": {
#                     "name": "data-loss-protect",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "3": {
#                     "name": "initial-routing-sync",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "7": {
#                     "name": "gossip-queries",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "9": {
#                     "name": "tlv-onion",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "11": {
#                     "name": "unknown",
#                     "is_required": false,
#                     "is_known": false
#                 },
#                 "13": {
#                     "name": "static-remote-key",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "15": {
#                     "name": "payment-addr",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "17": {
#                     "name": "multi-path-payments",
#                     "is_required": false,
#                     "is_known": true
#                 },
#                 "19": {
#                     "name": "wumbo-channels",
#                     "is_required": false,
#                     "is_known": true
#                 }
#             }
#         }
#     ],
#     "edges": [
#         {
#             "channel_id": "118747255865345",
#             "chan_point": "34a63fdad61ead2179d2313839c5579daa654278b757883d0f803466e839d36a:1",
#             "last_update": 1616422271,
#             "node1_pub": "02e7857b03623747741064fdd161a9a7579b6b5af178cf2836895b8f755843a7d7",
#             "node2_pub": "03f5f96163d4868f91358134dd95b162d0d3b1951612d63cf9cf94657ff602e6ec",
#             "capacity": "250000",
#             "node1_policy": {
#                 "time_lock_delta": 6,
#                 "min_htlc": "1",
#                 "fee_base_msat": "1",
#                 "fee_rate_milli_msat": "10",
#                 "disabled": false,
#                 "max_htlc_msat": "247500000",
#                 "last_update": 1614859513
#             },
#             "node2_policy": {
#                 "time_lock_delta": 40,
#                 "min_htlc": "1000",
#                 "fee_base_msat": "1000",
#                 "fee_rate_milli_msat": "1",
#                 "disabled": false,
#                 "max_htlc_msat": "250000000",
#                 "last_update": 1616422271
#             }
#         },
#         {
#             "channel_id": "131941395398657",
#             "chan_point": "9ead43a590cfaf258899c39f7eea42f2629e9cc41e1a743209b69f4b33241bf1:1",
#             "last_update": 1616422288,
#             "node1_pub": "03f5f96163d4868f91358134dd95b162d0d3b1951612d63cf9cf94657ff602e6ec",
#             "node2_pub": "03f706f9a86e0bb0cb1a812eef2abb9f2a2910bdcae792f4f6a3d5c817fedb8104",
#             "capacity": "250000",
#             "node1_policy": {
#                 "time_lock_delta": 40,
#                 "min_htlc": "1000",
#                 "fee_base_msat": "1000",
#                 "fee_rate_milli_msat": "1",
#                 "disabled": false,
#                 "max_htlc_msat": "250000000",
#                 "last_update": 1616422271
#             },
#             "node2_policy": {
#                 "time_lock_delta": 144,
#                 "min_htlc": "1",
#                 "fee_base_msat": "1000",
#                 "fee_rate_milli_msat": "100",
#                 "disabled": false,
#                 "max_htlc_msat": "250000000",
#                 "last_update": 1616422288
#             }
#         },
#         {
#             "channel_id": "138538465165313",
#             "chan_point": "d3377798a991f8221ca2332bb389b389e6a0a6a2149cb92ebd707f30a9de1480:1",
#             "last_update": 1616422288,
#             "node1_pub": "02e7857b03623747741064fdd161a9a7579b6b5af178cf2836895b8f755843a7d7",
#             "node2_pub": "03f706f9a86e0bb0cb1a812eef2abb9f2a2910bdcae792f4f6a3d5c817fedb8104",
#             "capacity": "250000",
#             "node1_policy": {
#                 "time_lock_delta": 6,
#                 "min_htlc": "1",
#                 "fee_base_msat": "1",
#                 "fee_rate_milli_msat": "10",
#                 "disabled": false,
#                 "max_htlc_msat": "247500000",
#                 "last_update": 1614859543
#             },
#             "node2_policy": {
#                 "time_lock_delta": 144,
#                 "min_htlc": "0",
#                 "fee_base_msat": "1000",
#                 "fee_rate_milli_msat": "100",
#                 "disabled": false,
#                 "max_htlc_msat": "250000000",
#                 "last_update": 1616422288
#             }
#         }
#     ]
# }
# ```
#
# ## make header
#
# `echo 'node1_pub, node2_pub, capacity, channel_id' > describegraph.csv`
#
# ## pipe output of LND node to jq, filter for edges and arrange src, sink and edge attributes for parsing
#
# ```bash
#     $ lncli describegraph |                                                               //
#         jq -r '.edges | .[] | [.node1_pub, .node2_pub, .capacity, .channel_id] | @csv' >> //
#         describe_edges.csv
# ```
#
# ```python
# df = pd.read_csv('describe_edges.csv', sep=',')
# G = nx.from_pandas_edgelist(df, "node1_pub", "node2_pub", ["capacity", "channel_id"])
# ```
#
# # for nodes
# ```bash
#     $ lncli describegraph |                                         //
#         jq -r '.nodes | .[] | [.pub_key, .alias, .color] | @csv' >> //
#         describe_nodes.csv
# ```

# %%
import pandas as pd
pd.set_option("display.precision", 2)
import numpy as np

import networkx as nx
from nxviz import ArcPlot
from nxviz import CircosPlot

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [250, 125]

import itertools as it

# %%
# convert edges in csv to dataframe
edges_df = pd.read_csv('cleaned/682223.csv', sep=',', names=["node1_pub", "node2_pub", "capacity", "channel_id"], dtype={"node1_pub": str, "node2_pub": str, "capacity": int, "channel_id": str})

edges_df
# filter small channels less than one million sats
#edges_df = edges_df.loc[edges_df['capacity'] > 5_000_000]
print(f'channel average {edges_df.capacity.mean()}')
print(f'channel median {edges_df.capacity.median()}')
# convert dataframe to graph 
G = nx.from_pandas_edgelist(edges_df, "node1_pub", "node2_pub", edge_attr=["capacity"])
print(nx.info(G))
# Out:
# channel average 2813188.9427378336
# channel median 500000.0
# Name:
# Type: Graph
# Number of nodes: 11399
# Number of edges: 40885
# Average degree:   7.1734

# %%
# bigG = nx.from_pandas_edgelist(pd.read_csv('describe_edges_mainnet.csv', sep=','), \
#                                "node1_pub", "node2_pub", ["capacity", "channel_id"])
# # basic network stats
# print(f"""
# {'-'*40}
#     Unfiltered
#     Number of LN nodes:             {bigG.order()}
#     Number of LN payment channels:  {bigG.size()}
#     Density of LN:                  {nx.classes.function.density(bigG)}
#     Number of connected components: {len(list(nx.connected_components(bigG)))}
#     Maximal independent set:        {len(nx.algorithms.maximal_independent_set(bigG))}
#     Number of bridges:              {len(list(nx.algorithms.bridges(bigG)))}
#     Size of the dominating set:     {len(nx.algorithms.dominating_set(bigG))}
#     LN is Chordal graph:            {nx.algorithms.chordal.is_chordal(bigG)}
#     LN degree assortativity:        {nx.algorithms.assortativity.degree_assortativity_coefficient(bigG)}
#     LN's transitivity:              {nx.algorithms.cluster.transitivity(bigG)}
# {'-'*40}
# """)

# %%
# basic network stats
print(f"""
{'-'*40}
    Number of LN nodes:             {G.order()}
    Number of LN payment channels:  {G.size()}
    Diameter of LN:                 
    Average clustering coeffecent   {nx.average_clustering(G)}        
    number of triangles             {sum([len(n) for n in nx.triangles(G)])}
    Density of LN:                  {nx.classes.function.density(G)}
    Number of connected components: {len(list(nx.connected_components(G)))}
    Maximal independent set:        {len(nx.algorithms.maximal_independent_set(G))}
    Number of bridges:              {len(list(nx.algorithms.bridges(G)))}
    Size of the dominating set:     {len(nx.algorithms.dominating_set(G))}
    LN is Chordal graph:            {nx.algorithms.chordal.is_chordal(G)}
    LN degree assortativity:        {nx.algorithms.assortativity.degree_assortativity_coefficient(G)}
    LN's transitivity:              {nx.algorithms.cluster.transitivity(G)}
    Average Channel size            {edges_df.capacity.mean()}
{'-'*40}
""")
print(f"{sum([G.degree(i) for i in G])/G.order()}")

#     LN average clustering coefficient {approximation.clustering_coefficient.average_clustering(G)}
#     Average shortest paths: {nx.algorithms.shortest_paths.generic.average_shortest_path_length(G)}
#     LN's largest clique size:  {nx.algorithms.approximation.clique.max_clique(G)}
#     Adjacency spectrum of LN:  {nx.linalg.spectrum.adjacency_spectrum(G)}
# Out:
# ----------------------------------------
#     Number of LN nodes:             11399
#     Number of LN payment channels:  40885
#     Diameter of LN:
#     Average clustering coeffecent   0.15496597628381173
#     number of triangles             752334
#     Density of LN:                  0.0006293592091892571
#     Number of connected components: 82
#     Maximal independent set:        8594
#     Number of bridges:              5274
#     Size of the dominating set:     8589
#     LN is Chordal graph:            False
#     LN degree assortativity:        -0.2293258360487141
#     LN's transitivity:              0.03888652709656734
#     Average Channel size            2813188.9427378336
# ----------------------------------------
#
# 7.173436266339152

# %%
# Top Ten Nodes for highest degree
# print("""
# {'-'*40}
#     Number of LN nodes:             {G.order()}
# {'-'*40}
# """)

# %%
# Top Ten Nodes for clustering coeffecint
# print("""
# {'-'*40}
#     Number of LN nodes:             {G.order()}
# {'-'*40}
# """)

# %%
# convert nodes in csv to dataframe
nodes_df = pd.read_csv('describe_nodes_mainnet.csv', sep=',')

# sanity check, sym diff between pubkeys in nodes and edges must be zero before filtering any edges

nodes_df.describe() # sanity check, pubkey count == pubkey unique
# Out:
#                                                   pub_key  \
# count                                                9776
# unique                                               9776
# top     03c7cad7e4ecfc741909b910d59b31b631e36afffc58e8...
# freq                                                    1
#
#                          alias    color
# count                     8150     9776
# unique                    7921     1227
# top     mynodebtc.com [myNode]  #3399ff
# freq                        98     3275

# %%
nodes_in_G = [n for n in G.nodes()]

# filter nodes if they are not in G 
nodes_df = nodes_df.loc[nodes_df['pub_key'].isin(nodes_in_G)]

nodes_df['neighbors'] = [G.neighbors(n) for n in nodes_df.pub_key]

# %%
betweeness_df = pd.DataFrame                                                                    \
    .from_dict(nx.betweenness_centrality(G), orient='index', columns=['betweeness_centrality']) \
    .reset_index()                                                                              \
    .rename(columns={'index': 'pub_key', 'betweeness_centrality': 'betweeness_centrality'})

nodes_df = pd.merge(nodes_df, betweeness_df, how="left", on=["pub_key"])

# %%
deg_cent_df = pd.DataFrame                                                             \
    .from_dict(nx.degree_centrality(G), orient='index', columns=['degree_centrality']) \
    .reset_index()                                                                     \
    .rename(columns={'index': 'pub_key', 'degree_centrality': 'degree_centrality'})

nodes_df = pd.merge(nodes_df, deg_cent_df, how="left", on=["pub_key"])

# %%
nodes_df['degree'] = [G.degree[n] for n in nodes_df.pub_key]

# sanity check neighbors and degree

# %%
def plot_degree_betweenness(G):
    """Plot scatterplot between degree and betweenness centrality."""

    df = pd.DataFrame(dict(bc=bc, dc=dc))
    ax = df.plot(x="dc", y="bc", kind="scatter")
    ax.set_ylabel("Betweenness\nCentrality")
    ax.set_xlabel("Degree Centrality")
    sns.despine()

# %%
def normalize(x, col_max):
    if x == -1:
        return np.nan
    else:
        return x/col_max
    
nodes_df.betweeness_centrality = nodes_df.betweeness_centrality \
                                    .apply(lambda x: normalize(x, nodes_df.betweeness_centrality.max()))

nodes_df.degree_centrality = nodes_df.degree_centrality \
                                    .apply(lambda x: normalize(x, nodes_df.degree_centrality.max()))

# %%
nodes_df.head(10)

# %%
# nodes_df.sort_values('betweeness_centrality', ascending=False).head(100).to_csv('tophundredbetweeness')

# %%
# list(nx.connected_components(G))

# %%
plt.rcParams['figure.figsize'] = [250, 125]

# %%
# nx.draw(G)

# %%
# nx.draw_spring(G)

# %%
# nx.draw_kamada_kawai(G)
# plt.savefig("kamada_kawai.png")

# %%
# nx.draw_networkx_edge_labels(G, pos=nx.kamada_kawai_layout(G))

# %%
# nx.draw_circular(G)

# %%
# nx.draw_shell(G)

# %%
# nx.draw_spectral(G)

# %%
def ecdf(data):
    return np.sort(data), np.arange(1, len(data) + 1) / len(data)

# %%
def ecdf_degree_centrality(G):
    """ECDF of degree centrality."""
    x, y = ecdf(list(nx.degree_centrality(G).values()))
    plt.scatter(x, y)
    plt.xlabel("degree centrality")
    plt.ylabel("cumulative fraction")

# %%
plt.rcParams['figure.figsize'] = [20, 10]
ecdf_degree_centrality(G)

# %%
def ecdf_degree(G):
    """ECDF of degree."""
    num_neighbors = [len(list(G.neighbors(n))) for n in G.nodes()]
    x, y = ecdf(num_neighbors)
    plt.scatter(x, y)
    plt.xlabel("degree")
    plt.ylabel("cumulative fraction")

# %%
ecdf_degree(G)

# %%
def ecdf_betweenness_centrality(G):
    """ECDF of betweeness centrality."""
#     expensive call
    x, y = ecdf(list(nx.betweenness_centrality(G).values()))
    plt.scatter(x, y)
    plt.xlabel("betweenness centrality")
    plt.ylabel("cumulative fraction")

# %%
ecdf_betweenness_centrality(G)

# %%
# take the 
# new dataframe with node id and then the ids of its neighbors in the other colunm

# %%
def ecdf_cliques(G):
    clique_size = [len(i) for i in nx.find_cliques(G)]
    x, y = ecdf(clique_size)
    print(x)
    plt.scatter(x, y)
    plt.xlabel("clique size")
    plt.ylabel("cumulative fraction")

# %%
ecdf_cliques(G)
# Out:
# [ 2  2  2 ... 26 26 26]

# %%
def find_k_cliques(G, k):
    """
    Find all cliques of size k.
    """
    for clique in nx.find_cliques(G):
        if len(clique) >= k:
            for nodeset in it.combinations(clique, k):
                yield nodeset

# %%
def label_connected_component_subgraphs(G):
    """Label all connected component subgraphs."""
    G = G.copy()
    for i, nodeset in enumerate(nx.connected_components(G)):
        for n in nodeset:
            G.nodes[n]["subgraph"] = i
    return G

# %%
def plot_cc_subgraph(G):
    """Plot all connected component subgraphs."""
    c = CircosPlot(G, node_color="subgraph", node_order="subgraph")
    c.draw()

# %%
list(find_k_cliques(G, 3))
# Out:
# [('034f1ec90e841677f8463600c5468f4e0409ae7d04b24885eb6f01912b85e295c3',
#   '02d246c519845e7b23b02684d64ca23b750958e0307f9519849ee2535e3637999a',
#   '036345e4b4393d0d25820b9db3f9dd2c98deed16e1c352a3d94e755ac3704e0b6b'),
#  ('034f1ec90e841677f8463600c5468f4e0409ae7d04b24885eb6f01912b85e295c3',
#   '02d246c519845e7b23b02684d64ca23b750958e0307f9519849ee2535e3637999a',
#   '038fe3c921a6bc389d28fc6a47e131b07adfb36450bfc1553d6445b182eb84c9bd'),
#  ('034f1ec90e841677f8463600c5468f4e0409ae7d04b24885eb6f01912b85e295c3',
#   '02d246c519845e7b23b02684d64ca23b750958e0307f9519849ee2535e3637999a',
#   '0399cd9a37f87b2ac5b8f336e46490d32ba85bc763c09e3ab07429596292a3a1e8'),
#  ('034f1ec90e841677f8463600c5468f4e0409ae7d04b24885eb6f01912b85e295c3',
#   '038fe3c921a6bc389d28fc6a47e131b07adfb36450bfc1553d6445b182eb84c9bd',
#   '0399cd9a37f87b2ac5b8f336e46490d32ba85bc763c09e3ab07429596292a3a1e8'),
#  ('02d246c519845e7b23b02684d64ca23b750958e0307f9519849ee2535e3637999a',
# ...

# %%
plot_cc_subgraph(label_connected_component_subgraphs(G))

# %% [markdown]
# + take three four and five and six cliques
# + (3 clique U 4 clique U 5 clique U 6 clique )
